# %% [markdown]
# # ENACCHI_colab版の使い方
# 1. 右上の下向き矢印をクリック
# 2. 「ランタイムのタイプを変更」をクリック
# 3. 選択肢のうち、GPUを選択
# 4. ランタイムを接続をクリック
# 5. 左上の「すべてのセルを実行」をクリック
# 6. 一番下のコードブロックに表示されるURLのうち、public URLの方をクリック
# 7. 立ち上がった画面でアプリ操作開始

# %%
# !git clone https://github.com/nappaniconico/ENACCHI_linux.git
# %cd ENACCHI_linux
# !pip install uv -q
# !uv sync
# Out:
# Cloning into 'ENACCHI_linux'...
# remote: Enumerating objects: 120, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 120 (delta 4), reused 11 (delta 3), pack-reused 106 (from 3)
# Receiving objects: 100% (120/120), 83.51 MiB | 39.55 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# /content/ENACCHI_linux
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 125.1 MB/s eta 0:00:00
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 57 packages in 0.71ms
# Prepared 54 packages in 3.32s
# Installed 54 packages in 143ms
#  + aiofiles==24.1.0
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + brotli==1.2.0
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + fastapi==0.128.0
#  + ffmpy==1.0.0
#  + filelock==3.20.3
#  + fsspec==2026.1.0
#  + gradio==6.3.0
#  + gradio-client==2.0.3
#  + groovy==0.1.2
# ...

# %%
# %%bash
# if nvidia-smi >/dev/null 2>&1; then
#     echo "GPUあり"
#     cd ./llama.cpp/build/bin
#     sudo apt-get install zip unzip
#     unzip libggml-cuda.so.0.9.zip
#     cp llama-server ../../..
#     cd ../../..
# else
#     echo "GPUなし"
#     cd ./llama.cpp/build_colab_cpu/bin
#     cp llama-server ../../..
#     cd ../../..
# fi
# Out:
# GPUあり
# Reading package lists...
# Building dependency tree...
# Reading state information...
# zip is already the newest version (3.0-12build2).
# unzip is already the newest version (6.0-26ubuntu3.2).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Archive:  libggml-cuda.so.0.9.zip
#   inflating: libggml-cuda.so.0.9.5
#   inflating: libggml-cuda.so.0

# %%
# !chmod +x ./llama-server

# %%
# !python main_llamacpp_colab.py

# %% [markdown]
# # 上のブロックに表示されるURLのうち、下のpublic URLをクリックしてください
