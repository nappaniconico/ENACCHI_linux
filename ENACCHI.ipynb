# %% [markdown]
# # ENACCHI_colab版の使い方
# 1. 右上の下向き矢印をクリック
# 2. 「ランタイムのタイプを変更」をクリック
# 3. 選択肢のうち、GPUを選択
# 4. ランタイムを接続をクリック
# 5. 左上の「すべてのセルを実行」をクリック
# 6. 一番下のコードブロックに表示されるURLのうち、public URLの方をクリック
# 7. 立ち上がった画面でアプリ操作開始

# %%
# !git clone https://github.com/nappaniconico/ENACCHI_linux.git
# %cd ENACCHI_linux
# !pip install uv -q
# !uv sync
# Out:
# Cloning into 'ENACCHI_linux'...
# remote: Enumerating objects: 233, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 233 (delta 70), reused 114 (delta 62), pack-reused 106 (from 3)
# Receiving objects: 100% (233/233), 108.84 MiB | 15.79 MiB/s, done.
# Resolving deltas: 100% (128/128), done.
# /content/ENACCHI_linux
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 93.1 MB/s eta 0:00:00
# Using CPython 3.12.12 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 57 packages in 0.60ms
# Prepared 54 packages in 1.83s
# Installed 54 packages in 208ms
#  + aiofiles==24.1.0
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + brotli==1.2.0
#  + certifi==2026.1.4
#  + charset-normalizer==3.4.4
#  + click==8.3.1
#  + fastapi==0.128.0
#  + ffmpy==1.0.0
#  + filelock==3.20.3
#  + fsspec==2026.1.0
#  + gradio==6.3.0
#  + gradio-client==2.0.3
#  + groovy==0.1.2
#  + h11==0.16.0
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
#  + httpx==0.28.1
#  + huggingface-hub==1.3.1
#  + idna==3.11
#  + jinja2==3.1.6
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + mdurl==0.1.2
#  + numpy==2.4.1
#  + orjson==3.11.5
#  + packaging==25.0
#  + pandas==2.3.3
#  + pillow==12.1.0
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pydub==0.25.1
#  + pygments==2.19.2
#  + python-dateutil==2.9.0.post0
#  + python-multipart==0.0.21
#  + pytz==2025.2
#  + pyyaml==6.0.3
#  + requests==2.32.5
#  + rich==14.2.0
#  + safehttpx==0.1.7
#  + semantic-version==2.10.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + starlette==0.50.0
#  + tomlkit==0.13.3
#  + tqdm==4.67.1
#  + typer==0.21.1
#  + typer-slim==0.21.1
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + tzdata==2025.3
#  + urllib3==2.6.3
#  + uvicorn==0.40.0

# %%
# !python main.py --colab

# %% [markdown]
# # 上のブロックに表示されるURLのうち、下のpublic URLをクリックしてください
